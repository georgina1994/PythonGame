# %% [raw]
# """DocString:
#
# A) Introduction:
#
# Mother earth is calling you for a mission. The player will need to accomplish three
# stages to save the world. The stages are designed to help the player understand how
# important it is protecting the Earth's natural resources, ecosystems, climate, and
# atmosphere so that current generations and future generations will have the things
# they need to live
# a decent life. Are you ready to save the world?
# If so, make sure to drink water and eat some snacks because you will travel around the
# world with the purpose of discovering the hidden 'clue' at the end of each stage.
#
# Game: Flying words
# Game: Quiz
# Game: Pairs
#
#
# B) Known Bugs and/or Errors: None."""
# import random
# import time
# import sys
# points = 0
# completed_continent = []
# completed_games_list = []
# advance_in_the_game = 0
#
# def intro():
#     completed_continent = []
#     completed_games_list = []
#     advance_in_the_game = 0
#     points = 0
#     global myname
#     print("""
#                                 ____                    __          __
#                                / __ \ ___   ____ _ ____/ /__  __   / /_ ____
#                               / /_/ // _ \ / __ `// __  // / / /  / __// __ \
#                              / _, _//  __// /_/ // /_/ // /_/ /  / /_ / /_/ /  _    _    _
#                             /_/ |_| \___/ \__,_/ \__,_/ \__, /   \__/ \____/  (_)  (_)  (_)
#                                                        /____/
#
#
#
#                                            _-o#&&*''''?d:>b\_
#                                       _o/"`''  '',, dMF9MMMMMHo_
#                                     .o&#'        `"MbHMMMMMMMMMMMHo.
#                                   .o"" '         vodM*$&&HMMMMMMMMMM?.
#                                 ,'              $M&ood,~'`(&##MMMMMMHH
#                                /               ,MMMMMMM#b?#bobMMMMHMMML
#                               &              ?MMMMMMMMMMMMMMMMM7MMM$R*Hk
#                              ?$.            :MMMMMMMMMMMMMMMMMMM/HMMM|`*L
#                             |               |MMMMMMMMMMMMMMMMMMMMbMH'   T,
#                             $H#:            `*MMMMMMMMMMMMMMMMMMMMb#}'  `?
#                             ]MMH#             ""*"*"*#MMMMMMMMMMMMM'    -
#                             MMMMMb_                   |MMMMMMMMMMMP'     :
#                             HMMMMMMMHo                 `MMMMMMMMMT       .
#                             ?MMMMMMMMP                  9MMMMMMMM}       -
#                             -?MMMMMMM                  |MMMMMMMMM?,d-    '
#                              :|MMMMMM-                 `MMMMMMMT .M|.   :
#                               .9MMM[                    &MMMMM*' `'    .
#                                :9MMk                    `MMM#"        -
#                                  &M}                     `          .-
#                                   `&.                             .
#                                     `~,   .                     ./
#                                         . _                  .-
#                                            '`--._,dd###pp=""'
#
#                                                                                                   #####
#       ####    ##   #    # ######    ##### #    # ######    #    #  ####  #####  #      #####     #     #
#      #       #  #  #    # #           #   #    # #         #    # #    # #    # #      #    #          #
#       ####  #    # #    # #####       #   ###### #####     #    # #    # #    # #      #    #       ###
#           # ###### #    # #           #   #    # #         # ## # #    # #####  #      #    #       #
#      #    # #    #  #  #  #           #   #    # #         ##  ## #    # #   #  #      #    #
#       ####  #    #   ##   ######      #   #    # ######    #    #  ####  #    # ###### #####        #
#                                                                                                          """)
#
#
#     #import randomization and time in the game
#     import random
#     import time
#
#     while True:
#         skip = input ("\n\n\nWould you like to go through the introduction quickly?[Yes/No]\t").lower()
#
#         if "no" in skip:
#             message = ("""\n\n\nHi!!! You...?! Yes!!!! I am talking to you... mh... mh... What was your name again?\t""")
#             for letter in message:
#         # printing each character of the message
#                print(letter, end='')
#                time.sleep(0.09)
#
#             myname = input().capitalize()
#
#             message2 = (f"""\nSo sorry {myname}, I haven\'t been eating healthy the last years and my memory is getting worse
# and worse!... Also, my skin... Sometimes I get burn and the firefighters throw me water to calm down. Arg...
# it's almost winter time but I feel like summer. It must be global warming that is getting worse every day!
# Sometimes I wish I would be 'Uranus' or 'Neptune' they must be cold!""")
#
#             for letter in message2:
#         # printing each character of the message
#                print(letter, end='')
#                time.sleep(.09)
#
#             message3 = ("""\nAnyway, first things first. Let me introduce myself. I am mother earth and you have been selected for a mission.
# \nAre you ready?""")
#
#             for letter in message3:
#         # printing each character of the message
#                print(letter, end='')
#                time.sleep(.09)
#         #add the funtion if Yes or if Not
#             while True:
#                 ans = input ('(Yes, I am!!! / No... I am scared) << ').lower()
#                 if "yes" in ans or "y" in ans:
#                     message4 = (f"""\nAwesome {myname}! Lately, I haven't been treated well that my body temperature has been rising.
# For instance, the effects on global climate change are already observables. Glaciers have shrunk, ice on
# rivers and lakes is breaking up earlier, plant and animal ranges have shifted and trees are flowering sooner.
# Your mission is to learn about different topics that can help me to last more years. At the end of each level you
# will receive a clue, that is the key to transfer this message around the world. Take some snacks and water because
# you will travel on some continents. Let's encourage your generation to save ME: your planet!""")
#                     for letter in message4:
#                        # printing each character of the message
#                         print(letter, end='')
#                         time.sleep(.09)
#                         continents()
#
#                 elif "no" in ans or "n" in ans:
#                     print(f"I am sorry {myname}. I hope you can join me on this mission sometime soon...")
#                     fail()
#                 else:
#                     print("\nAre you with me in this mission? [Yes/No]\t")
#
#         elif "yes" in skip:
#             message = """\n\n\nHi!!! You...?! Yes!!!! I am talking to you... mh... mh... What was your name again?\t"""
#             print(message)
#
#             myname = input().capitalize()
#
#             message2 = (f"""\nSo sorry {myname}, I haven\'t been eating healthy the last years and my memory is getting worse
# and worse!... Also, my skin... Sometimes I get burn and the firefighters throw me water to calm down. Arg...
# it's almost winter time but I feel like summer. It must be global warming that is getting worse every day!
# Sometimes I wish I would be 'Uranus' or 'Neptune' they must be cold!""")
#
#             print(message2)
#
#             message3 = ("""\nAnyway, first things first. Let me introduce myself. I am mother earth and you have been selected for a mission.
# \nAre you ready?""")
#
#             print(message3)
#             #add fail funtion
#             while True:
#                 ans = input ('(Yes, I am!!! / No... I am scared) << ').lower()
#                 if "yes" in ans or "y" in ans:
#                     message4 = (f"""\nAwesome {myname}! Lately, I haven't been treated well that my body temperature has been rising.
# For instance, the effects on global climate change are already observables. Glaciers have shrunk, ice on
# rivers and lakes is breaking up earlier, plant and animal ranges have shifted and trees are flowering sooner.
# Your mission is to learn about different topics that can help me to last more years. At the end of each level you
# will receive a clue, that is the key to transfer this message around the world. Take some snacks and water because
# you will travel on some continents. Let's encourage your generation to save ME: your planet!""")
#                     print(message4)
#                     continents()
#
#                 elif "no" in ans or "n" in ans:
#                     print(f"I am sorry {myname}. I hope you can join me on this mission sometime soon...")
#                     fail()
#                 else:
#                     print("\nAre you with me in this mission? [Yes/No]\t")
#
#         else:
#             print("\nSorry, would you like to skip the introduction? (YES/NO)" )
#
#
#
# #while loop in order to make sure the player picks the first continent
# def continents():
#     global completed_continent
#     global completed_games_list
#     global myname
#     global advance_in_the_game
#     global points
#     if points > 50 and advance_in_the_game > 2:
#         final()
#     elif advance_in_the_game > 2 and points < 0:
#         print("You completed all the games, but you don't have enough points")
#         fail()
#     else:
#
#         #to generate the 'clues' at the end of each stage.
#         # Look for more clues.
#         clues = [["oceania", "The kangaroo is native from this continent."],
#                  ["oceania", "The smallest continent in the planet."],
#                  ["europe", "The continent that houses the two smallest countries in the world."],
#                  ["europe", "The continent with the northernmost capital city."],
#                  ["america", "Only continent both in north and south emisphere."],
#                  ["america", "The driest place on earth is in this continent."],
#                  ["asia", "The continent where most languages are spoken."],
#                  ["asia", "The largest city in the world is in this continent."],
#                  ["antartica", "The continent with the smallest population."],
#                  ["antartica", "The continent storing the most fresh water in the world."],
#                  ["africa", "Where the oldest human fossils have been discovered."],
#                  ["africa", "The continent that has the most countries."]]
#         time.sleep(1)
#         if advance_in_the_game == 0:
#             game = random.randint(0,2) #Making the first game being random
#             while True:
#                 print(f"""\nWhere would you like to start the mission, {myname}?
# Please pick a continent from the list below:
#
#             Europe
#             America
#             Africa
#             Oceania
#             Asia
#             Antartica
#         """)
#                 continent1 = input().lower()
#                 if 'europe' in continent1 or 'america' in continent1 or 'africa' in continent1 or 'oceania' in continent1 or 'asia' in continent1 or 'antartica' in continent1:
#                     completed_continent.append(continent1)
#                     print (f"""\nLet\'s go {myname}!""")
#                     break
#                 else:
#                     print("That's not a continent, please pick one from the list\n")
#
#             #you can modify the range of randint to test each game separetely
#
#             if game == 0:
#                 flying_words()
#             elif game == 1:
#                 quiz()
#             elif game == 2:
#                 pairs()
#
#         if advance_in_the_game > 0:
#
#             while True: #This while loop generates a random number to pick a random clue
#                 y = random.randint(0,len(clues)-1)
#                 if clues[y][0] in completed_continent: # If the random number y, gives a continent that is already taken, we start the loop again
#                     pass
#                 else: # When the random number y, gives a continent that is NOT taken, we break the loop to give the user a random clue
#                     break
#
#             print(f"""\n\nGood job! You are doing great! Oh... wait! In order to use again the teleporter
# ship you will need to guess this riddle related to one of the continents listed below:
# '{clues[y][1]}'""")
#
#             #When the clues start
#             while True:
#                 print(f"""\n{myname}, which is your guess?:
#
#             Europe
#             America
#             Africa
#             Oceania
#             Asia
#             Antartica
#         """)
#                 #I want to control the continent that the gamer goes and make sure the
#                 #player does not go again to the same continent
#                 continent1 = input().lower()
#                 if continent1 in completed_continent:
#                     print(f"\n{myname} you have already been in {continent1}.")
#                 elif continent1 not in clues[y][0]:
#                     print("\nTry again! This is not a correct answer.")
#                 else:
#                     if 'europe' in continent1 or 'america' in continent1 or 'africa' in continent1 or 'oceania' in continent1 or 'asia' in continent1 or 'antartica' in continent1:
#                         completed_continent.append(continent1)
#                         while True:
#                             game = random.randint(0,2)
#                             if game == 0 and "flying_words" not in completed_games_list:
#                                 flying_words()
#                             elif game == 1 and "quiz" not in completed_games_list:
#                                 quiz()
#                             elif game == 2 and "pairs" not in completed_games_list:
#                                 pairs()
#                             else:
#                                 pass
#                         return continent1
#                     else:
#                         print("\nThat's not a continent, please pick one from the list")
#                         continue
#
# #game1
# def flying_words():
#     global completed_games_list
#     global advance_in_the_game #Adding global to avoid python to create a new variable when updating the value of 'advance_in_the_game'. Resource (Second answer of the thread): https://stackoverflow.com/questions/10851906/python-3-unboundlocalerror-local-variable-referenced-before-assignment/10852003
#     global points
#     advance_in_the_game += 1
#     #list of items to recycle
#     org_list = ["rotten strawberries","egg shells", "apple peel", "husks","onion peel", "rotten lemon", "flowers", "orange peel", "tea leaves", "pile of wood", "damaged food", "grass clippings", "watermelon rind "]
#     new =[]
#     for i in org_list:
#         new.append(["compost", i])
#     #recycle
#     rec_list = ["plastic bottle", "milk carton", "metal bottle caps", "plastic zipper bag", "glass bottle", "paper egg carton", "colored waste papers", "cardboard box", "soda can", "aluminium can", "foil containers"]
#     new2 = []
#     for i in rec_list:
#         new2.append(["recycle", i])
#     #trash
#     trash_list = ["candy wrapper", "empty tooth paste", "light bulb", "diaper", "broken shoe", "chocolate wrappers", "broken ceramic cup"]
#     new3 = []
#     for i in trash_list:
#         new3.append(["trash", i])
#
#     all_products = new + new2 + new3
#
# #explanation of flying words
#     print (f"""\nWelcome {myname}!
# In this continent you will need to classify waste material in their corresponding container.
# Flying waste material will appear and you will need to be precise on categorizing the waste.
# I recieve a around 2.12 billion tons of waste every year. It's a lot!!! I know.. :(...!!
# That's why you are in this mission to learn these skills and save me!
#
# Please classify the trash in the following containers by typing the name of the container:
# Hint [compost, recycle or trash] \n""")
#
#     input("<Press Enter To Continue>")
#
# #while loop to count points and import random
#     i = 0
#     attempts = 5
#     random_repeated = [] # list to store repeated random numbers
#     while i < attempts:
#         time.sleep(1)
#         x = random.randint(0,len(all_products)-1) #generate a random number to randomize the flying words
#
#         if x not in random_repeated:
#             print (f"""\n\n
#            - Compost bin
#            - Recycle bin
#            - Trash bin """)
#             answer = input(f"In which container \"{all_products[x][1]}\" goes? ").lower()
#
#             if all_products[x][0] in answer:
#                 print(f"\n\nGood job, I see you have great recycling skills!, you have {attempts - i} more rounds")
#                 points += 10 #accumulative points for every word correctly categorized
#
#             else:
#                 print (f"\n\nOh...no! That was incorrect :( , you have {attempts - i} more rounds")
#                 points -= 5 #discount points if you miss the correct categorization
#             i += 1
#             random_repeated.append(x) #add the numbers at the end of the list
#         if points < -10:
#             print("Ohh no... you have failed too much")
#             fail()
#         else:
#             pass
#     completed_games_list.append("flying_words") #adding the completed game to not repeat it
#     time.sleep(2)
#     print(f"""\n\n{myname} you got a total of {points} points to survive during the next continents.
# By accomplishing this stage you have unlocked one of the words to complete the final ENIGMA: """, end="")
#     time.sleep(2)
#     recycle = "RECYCLE"
#     for letter in recycle:
#         print(letter, end="")
#         time.sleep(0.5)
#     continents()
#
#
# #game2 Quiz = Random
#
# def quiz():
#     global completed_games_list
#     global advance_in_the_game #Adding global to avoid python to create a new variable when updating the value of 'advance_in_the_game'. Resource (Second answer of the thread): https://stackoverflow.com/questions/10851906/python-3-unboundlocalerror-local-variable-referenced-before-assignment/10852003
#     global points
#     advance_in_the_game +=1
#     print(f"""Welcome {myname}! In this continent you will need to answer some questions related to different sustainability topics.
# At the end of the quiz you will find a clue for the final enigma! Good luck :D""")
#     input("<Press Enter to continue>")
#     question = []
#     quiz = 0
#     while quiz < 4:
#
#         questions_energy = [
#             ["Which of these items can be composted, or turned into natural fertilizer, for your garden?", "Eggshells", "Golf balls", "Aluminium foil", "Plastic bag"],
#             ["What uses the most energy in U.S. homes each year?", "Heating", "Lighting", "Refrigeration", "Heating water"],
#             ["Which of these species are threatened by global warming?", "All", "Clownfish", "Artic fox", "Koala"],
#             ["How many degrees has the Earth warmed up in the past 100 years? (in ºF) ", "1", "20", "30", "12"],
#             ["What is the most frequently found in beach cleanups?", "Plastic", "Shoes", "Jewelry", "Glass"],
#             ["Paper can be made from which of these material?", "All", "Panda excrement", "Hemp", "Wood"],
#             ["Which is the greenest form of transportation?", "Bicycle", "Train", "Bus", "Car"]]
#
#         #create this while loop to randomize the questions
#         while True:
#             x = random.randint(0,6) #Random per la row de la llista questions_energy
#             if x not in question:
#                 time.sleep(2)
#                 print (f"\n\n{questions_energy[x][0]}")
#                 question.append(x)
#                 break
#             elif x in question:
#                 pass
#
#         #create this while loop to randomize the answers
#         answers = []
#         while len(answers) < 4: #while loop to randomize the printed options
#             y = random.randint(1,4) #Random per la row de resposta de la llista questions_energy
#             if y not in answers:
#                 print (f"{questions_energy[x][y]}")
#                 answers.append(y)
#             else:
#                 pass
#
#         #created this while loop to limit the chances
#         chances = 3
#         while chances > -1:
#             question1 = input ("> ").lower()
#             if questions_energy[x][1].lower() in question1:
#                 quiz += 1
#                 points +=8
#                 print(f"Amazing {myname}! ")
#                 break
#             elif chances == 0:
#                 fail()
#             else:
#                 print (f"\nTry again, you have {chances-1} more attempts")
#                 points -=3
#                 chances -= 1
#
#     completed_games_list.append("quiz") #adding the completed game to not repeat it
#     time.sleep(2)
#     print(f"""\n\n{myname} you got a total of {points} points to survive during the next continents.\n
# Write down this word to complete the FINAL ENIGMA: """, end="")
#     time.sleep(2)
#     reuse = "REUSE"
#     for letter in reuse:
#         print(letter, end="")
#         time.sleep(0.5)
#     continents()
#
# #game 3 Pairs = Random
#
# def pairs():
#     global completed_games_list
#     global advance_in_the_game #Adding global to avoid python to create a new variable when updating the value of 'advance_in_the_game'. Resource (Second answer of the thread): https://stackoverflow.com/questions/10851906/python-3-unboundlocalerror-local-variable-referenced-before-assignment/10852003
#     global points
#     advance_in_the_game +=1
#
#     pair_list = ["1. Reusable", "2. Swicht off", "3. Do not use", "4. Try to avoid", "5. Change light bulbs", "6. Ask for no straw", "7. Pick up", "8. Meal plan", "9. If you have leftover food" ]
#     pair_list2 = ["\t\t1. plastic bags", "\t\t2. water bottle", "\t\t3. pop it into your own container.", "\t\t4. lights", "\t5. in your drink order when out", "\t6. a lonely banana", "\t\t7. palm oil", "\t\t8. to LEDs", "9. to avoid food waste."]
#     good_list = ["12", "93", "24", "31", "65", "76", "58", "89", "47"]
#     answered_correctly = []
#
#     print (f"""Welcome! (sounds of rock music) Have you been drinking water? You should! Lots of travelings are taking place...
# Try to match the words from column A with the words with column B with the pourpose of forming a sentence with a hiden message for your living time on me: Your Planet!
# Hint: type the answer using the numbers from columnA and columnB respectively '25'""")
#     input("<Press Enter to continue>")
#
#     chances = 0
#     correct_answers = 0
#     while chances < 3 and correct_answers < 9:
#         print ("\n\nColumn A\t\t \t\tColumn B")
#         for p1,p2 in zip(pair_list,pair_list2):
#             print (p1 +"\t\t"+ p2)
#         player_answer = input ( )
#         if player_answer not in answered_correctly:
#             try:
#                 good_list.index(player_answer)
#                 answered_correctly.append(player_answer)
#                 print ("Amazing!!!!")
#                 correct_answers += 1
#                 print(f"{myname}, you have {correct_answers} correct. Only {9-correct_answers} to finish!")
#
#             except ValueError:
#                 chances += 1
#                 print(f"Try again! You have {3-chances} left")
#
#         elif player_answer in answered_correctly:
#             print("You have already answered this!")
#         else:
#             chances += 1
#             print(f"Try again! You have {3-chances} left")
#
#     if chances == 3:
#         fail()
#     elif correct_answers == 9:
#         points += 70
#         completed_games_list.append("pairs") #adding the completed game to not repeat it
#         time.sleep(2)
#         print(f"""\n\n{myname} you got a total of {points} points to survive during the next continents.
# Write down this word to complete the FINAL ENIGMA: """, end = "")
#         time.sleep(2)
#         reduce = "REDUCE"
#         for letter in reduce:
#             print(letter, end="")
#             time.sleep(0.5)
#         continents()
#     else:
#         print("Soemthing went wrong")
#
# def fail():
#     print("\nYou have failed in your mission to save the world.")
#     input("""<Game over>
#           <Press Enter to continue>""")
#
#     again = input("\nWould you like to play again?\n")
#     if "yes" in again:
#         intro()
#     elif "no" in again:
#         sys.exit(0)
#     else:
#         print("Something went wrong")
#         sys.exit(0)
#
# def final():
#     print("""\nGood joob!! How do you feel after traveling everywhere in just 4 minutes? Impressive ah...
# You reached the FINAL CHALLENGE, complete the sentence with the unlocked words:
# \nLet\'s ensure the world survival and...""")
#     final_list = []
#
#     final_answer1 = input(">").lower()
#     final_list.append(final_answer1)
#
#     final_answer2 = input(">").lower()
#     final_list.append(final_answer2)
#
#     final_answer3 = input(">").lower()
#     final_list.append(final_answer3)
#
#     if "reduce" in final_list and "reuse" in final_list and "recycle" in final_list:
#         print("CONGRATULATION!! YOU ACCOMPLISHED THE MISSION!!!")
#         again = input("\nWould you like to play again?\n")
#         if "yes" in again:
#             intro()
#         else:
#             pass
#     else:
#         print("Alsmost there.... ")
#         fail()
#
#
# intro()
